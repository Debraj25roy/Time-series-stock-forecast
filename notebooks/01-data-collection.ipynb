# %% [markdown]
# # 01-data-collection.ipynb
#
# This notebook demonstrates steps. Replace cells with interactive runs.

# %%
print('Run the data loader:')
from src.data_loader import download_ticker
print('Example: download_ticker(\"AAPL\", "2015-01-01", "2024-12-31")')
